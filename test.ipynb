# %%
import os
import openai
from dotenv import load_dotenv

# Load environment variables
load_dotenv()
key = os.getenv('API_KEY')

openai.api_key = key
openai.Engine.list()
# Out:
# <OpenAIObject list at 0x10afc0170> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "engine",
#       "id": "whisper-1",
#       "ready": true,
#       "owner": "openai-internal",
#       "permissions": null,
#       "created": null
#     },
#     {
#       "object": "engine",
#       "id": "babbage",
#       "ready": true,
#       "owner": "openai",
#       "permissions": null,
#       "created": null
#     },
#     {
#       "object": "engine",
#       "id": "davinci",
#       "ready": true,
#       "owner": "openai",
#       "permissions": null,
#       "created": null
#     },
#     {
#       "object": "engine",
#       "id": "text-davinci-edit-001",
#       "ready": true,
#       "owner": "openai",
#       "permissions": null,
#       "created": null
#     },
#     {
#       "object": "engine",
#       "id": "babbage-code-search-code",
#       "ready": true,
#       "owner": "openai-dev",
#       "permissions": null,
#       "created": null
#     },
#     {
# ...
